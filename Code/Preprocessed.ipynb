# %% [markdown]
# # Tiền xử lý dữ liệu thô

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ## Gộp file
# - Gộp 6 file csv chứa dữ liệu được parse từ web để tiền xử lí
# - file lưu tất cả dữ liệu là `data_phone.csv`
# - Lấy các dữ liệu có price và lưu vào file `data_phone_have_price.csv`

# %%
df1 = pd.read_csv('0_to_1000.csv', sep = '\t')
df2 = pd.read_csv('1000_to_2000.csv', sep = '\t')
df3 = pd.read_csv('2000_to_3000.csv', sep = '\t')
df4 = pd.read_csv('3000_to_4000.csv', sep = '\t')
df5 = pd.read_csv('4000_to_5000.csv', sep = '\t')
df6 = pd.read_csv('5000_to_5678.csv', sep = '\t')

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6], ignore_index=True)
df
# Out:
#      brand    technology            touch_screen display_colors screen_size  \
# 0       A1       IPS LCD  capacitive touchscreen            16M   6.26" inc
# 1       A1       IPS LCD  capacitive touchscreen            16M    5.5" inc
# 2     Acer  Super AMOLED  capacitive touchscreen            16M    5.5" inc
# 3     Acer       IPS LCD  capacitive touchscreen            16M      5" inc
# 4     Acer       IPS LCD  capacitive touchscreen            16M    5.5" inc
# ...    ...           ...                     ...            ...         ...
# 5672   Zte           TFT   resistive touchscreen           256K    2.5" inc
# 5673   Zte           TFT   resistive touchscreen           256K    2.8" inc
# 5674   Zte           TFT   resistive touchscreen           256K    2.5" inc
# 5675   Zte           TFT   resistive touchscreen            65K    3.2" inc
# 5676   Zte           TFT   resistive touchscreen            65K    2.5" inc
#
#      screen_area screen_to_body_ratio screen_resolution      rear_camera  \
# 0       97.8 cm2                82.1%     720 x 1520 px      13 MP, Dual
# 1       78.1 cm2                77.1%     720 x 1440 px    13 MP, Single
# 2       83.4 cm2                70.2%    1080 x 1920 px    21 MP, Single
# 3       68.9 cm2                65.3%     720 x 1280 px     8 MP, Single
# 4       83.4 cm2                71.7%    1080 x 1920 px    13 MP, Single
# ...          ...                  ...               ...              ...
# 5672    19.4 cm2                25.7%      320 x 240 px  3.15 MP, Single
# 5673    24.3 cm2                43.3%      240 x 320 px  3.15 MP, Single
# 5674    19.4 cm2                29.7%      320 x 240 px     2 MP, Single
# 5675    31.7 cm2                49.7%      240 x 320 px     5 MP, Single
# 5676    19.4 cm2                25.7%      320 x 240 px   3.2 MP, Single
#
#         front_camera  ...          net_work  \
# 0       8 MP, Single  ...  GSM / HSPA / LTE
# 1       8 MP, Single  ...  GSM / HSPA / LTE
# 2       8 MP, Single  ...  GSM / HSPA / LTE
# 3       2 MP, Single  ...  GSM / HSPA / LTE
# 4       5 MP, Single  ...  GSM / HSPA / LTE
# ...              ...  ...               ...
# 5672           0 MP,  ...       CDMA / EVDO
# 5673           0 MP,  ...        GSM / HSPA
# 5674           0 MP,  ...               GSM
# 5675  0.3 MP, Single  ...        GSM / HSPA
# 5676  0.3 MP, Single  ...        GSM / HSPA
#
#                                           speed      gprs  \
# 0     HSPA 42.2/5.76 Mbps, LTE Cat4 150/50 Mbps       Yes
# 1                    HSPA, LTE Cat4 150/50 Mbps       Yes
# 2     HSPA 42.2/5.76 Mbps, LTE Cat4 150/50 Mbps       Yes
# 3                                     HSPA, LTE       Yes
# 4     HSPA 42.2/5.76 Mbps, LTE Cat4 150/50 Mbps       Yes
# ...                                         ...       ...
# 5672                                       HSPA        No
# 5673                        HSPA 7.2/0.384 Mbps       Yes
# 5674                                        NaN  Class 10
# 5675                         HSPA 7.2/5.76 Mbps  Class 12
# 5676                        HSPA 7.2/0.384 Mbps  Class 10
#
#                            gps  \
# 0     Yes, with A-GPS, GLONASS
# 1              Yes, with A-GPS
# 2              Yes, with A-GPS
# 3              Yes, with A-GPS
# 4              Yes, with A-GPS
# ...                        ...
# 5672                        No
# 5673           Yes, with A-GPS
# 5674                        No
# 5675           Yes, with A-GPS
# 5676           Yes, with A-GPS
#
#                                                    wifi  \
# 0             Wi-Fi 802.11 b/g/n, Wi-Fi Direct, hotspot
# 1                           Wi-Fi 802.11 b/g/n, hotspot
# 2     Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Dire...
# 3                           Wi-Fi 802.11 b/g/n, hotspot
# 4             Wi-Fi 802.11 b/g/n, Wi-Fi Direct, hotspot
# ...                                                 ...
# 5672                                                 No
# 5673                                   Wi-Fi 802.11 b/g
# 5674                                                 No
# 5675                                    Wi-Fi 802.11b/g
# 5676                                    Wi-Fi 802.11b/g
#
#                           nfc                          usb      bluetooth  \
# 0     Yes (64/3GB model only)  microUSB 2.0, USB On-The-Go  4.2, A2DP, LE
# 1                         Yes                 microUSB 2.0      4.0, A2DP
# 2                         NaN                 microUSB 2.0  4.0, A2DP, LE
# 3                         NaN                 microUSB 2.0      4.0, A2DP
# 4                         NaN                 microUSB 2.0      4.0, A2DP
# ...                       ...                          ...            ...
# 5672                      NaN                 microUSB 2.0      2.0, A2DP
# 5673                      NaN                 microUSB 2.0      2.0, A2DP
# 5674                      NaN                 microUSB 2.0      2.0, A2DP
# 5675                      NaN                 microUSB 2.0      2.0, A2DP
# 5676                      NaN                 microUSB 2.0      2.0, A2DP
#
#                      radio headphone_jack
# 0                 FM radio            Yes
# 1                 FM radio            Yes
# 2                 FM radio            Yes
# 3                 FM radio            Yes
# 4                 FM radio            Yes
# ...                    ...            ...
# 5672                    No             No
# 5673  Stereo FM radio, RDS            Yes
# 5674  Stereo FM radio, RDS             No
# 5675  Stereo FM radio, RDS            Yes
# 5676  Stereo FM radio, RDS             No
#
# [5677 rows x 30 columns]

# %%
df.to_csv('data_phone.csv',index=False)

# %%
data_phone = pd.read_csv('data_phone.csv')

# %%
data_phone = data_phone[data_phone.approximate_price != 'None']

# %%
data_phone.to_csv('data_phone_have_price.csv',index=False)

# %%
phones_df = pd.read_csv('data_phone_have_price.csv')
phones_df
# Out:
#      brand     technology            touch_screen display_colors screen_size  \
# 0       A1        IPS LCD  capacitive touchscreen            16M   6.26" inc
# 1       A1        IPS LCD  capacitive touchscreen            16M    5.5" inc
# 2     Acer        IPS LCD  capacitive touchscreen            16M      5" inc
# 3     Acer        IPS LCD  capacitive touchscreen            16M    5.5" inc
# 4     Acer        IPS LCD  capacitive touchscreen            16M      5" inc
# ...    ...            ...                     ...            ...         ...
# 4279   Zte            TFT  capacitive touchscreen            16M    4.3" inc
# 4280   Zte            TFT  capacitive touchscreen            16M    4.3" inc
# 4281   Zte            TFT   resistive touchscreen            65K      0" inc
# 4282   Zte  AMOLED or LCD  capacitive touchscreen           256K    3.5" inc
# 4283   Zte            TFT   resistive touchscreen           256K    2.8" inc
#
#      screen_area screen_to_body_ratio screen_resolution      rear_camera  \
# 0       97.8 cm2                82.1%     720 x 1520 px      13 MP, Dual
# 1       78.1 cm2                77.1%     720 x 1440 px    13 MP, Single
# 2       68.9 cm2                65.3%     720 x 1280 px     8 MP, Single
# 3       83.4 cm2                71.7%    1080 x 1920 px    13 MP, Single
# 4       68.9 cm2                66.4%     720 x 1280 px     8 MP, Single
# ...          ...                  ...               ...              ...
# 4279    52.6 cm2                61.7%      480 x 800 px     5 MP, Single
# 4280    52.6 cm2                60.4%      480 x 800 px     5 MP, Single
# 4281         cm2                    %      320 x 240 px     2 MP, Single
# 4282    34.9 cm2                53.2%      480 x 800 px  3.15 MP, Single
# 4283    24.3 cm2                43.3%      240 x 320 px  3.15 MP, Single
#
#       front_camera  ...          net_work  \
# 0     8 MP, Single  ...  GSM / HSPA / LTE
# 1     8 MP, Single  ...  GSM / HSPA / LTE
# 2     2 MP, Single  ...  GSM / HSPA / LTE
# 3     5 MP, Single  ...  GSM / HSPA / LTE
# 4     5 MP, Single  ...  GSM / HSPA / LTE
# ...            ...  ...               ...
# 4279         0 MP,  ...        GSM / HSPA
# 4280         0 MP,  ...        GSM / HSPA
# 4281         0 MP,  ...               GSM
# 4282         0 MP,  ...        GSM / HSPA
# 4283         0 MP,  ...        GSM / HSPA
#
#                                           speed gprs  \
# 0     HSPA 42.2/5.76 Mbps, LTE Cat4 150/50 Mbps  Yes
# 1                    HSPA, LTE Cat4 150/50 Mbps  Yes
# 2                                     HSPA, LTE  Yes
# 3     HSPA 42.2/5.76 Mbps, LTE Cat4 150/50 Mbps  Yes
# 4                    HSPA, LTE Cat4 150/50 Mbps  Yes
# ...                                         ...  ...
# 4279                                       HSPA  Yes
# 4280                        HSPA 14.4/5.76 Mbps  Yes
# 4281                                        NaN  Yes
# 4282                         HSPA 7.2/5.76 Mbps  Yes
# 4283                        HSPA 7.2/0.384 Mbps  Yes
#
#                            gps                                       wifi  \
# 0     Yes, with A-GPS, GLONASS  Wi-Fi 802.11 b/g/n, Wi-Fi Direct, hotspot
# 1              Yes, with A-GPS                Wi-Fi 802.11 b/g/n, hotspot
# 2              Yes, with A-GPS                Wi-Fi 802.11 b/g/n, hotspot
# 3              Yes, with A-GPS  Wi-Fi 802.11 b/g/n, Wi-Fi Direct, hotspot
# 4              Yes, with A-GPS                Wi-Fi 802.11 b/g/n, hotspot
# ...                        ...                                        ...
# 4279           Yes, with A-GPS                  Wi-Fi 802.11 b/g, hotspot
# 4280           Yes, with A-GPS                         Wi-Fi 802.11 b/g/n
# 4281           Yes, with A-GPS                  Wi-Fi 802.11 b/g, hotspot
# 4282           Yes, with A-GPS    Wi-Fi 802.11 b/g, hotspot (Android 2.2)
# 4283           Yes, with A-GPS                           Wi-Fi 802.11 b/g
#
#                           nfc                          usb       bluetooth  \
# 0     Yes (64/3GB model only)  microUSB 2.0, USB On-The-Go   4.2, A2DP, LE
# 1                         Yes                 microUSB 2.0       4.0, A2DP
# 2                         NaN                 microUSB 2.0       4.0, A2DP
# 3                         NaN                 microUSB 2.0       4.0, A2DP
# 4                         NaN                 microUSB 2.0       4.0, A2DP
# ...                       ...                          ...             ...
# 4279                      NaN                 microUSB 2.0  2.1, A2DP, EDR
# 4280                      NaN                 microUSB 2.0  3.0, A2DP, EDR
# 4281                      NaN                 microUSB 2.0       2.1, A2DP
# 4282                      NaN                 microUSB 2.0  2.1, A2DP, EDR
# 4283                      NaN                 microUSB 2.0       2.0, A2DP
#
#                      radio headphone_jack
# 0                 FM radio            Yes
# 1                 FM radio            Yes
# 2                 FM radio            Yes
# 3                 FM radio            Yes
# 4                 FM radio            Yes
# ...                    ...            ...
# 4279                   NaN            Yes
# 4280  Stereo FM radio, RDS            Yes
# 4281              FM radio            Yes
# 4282  Stereo FM radio, RDS            Yes
# 4283  Stereo FM radio, RDS            Yes
#
# [4284 rows x 30 columns]

# %% [markdown]
# ## Khám phá dữ liệu

# %%
phones_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4284 entries, 0 to 4283
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   brand                 4284 non-null   object
#  1   technology            4126 non-null   object
#  2   touch_screen          4099 non-null   object
#  3   display_colors        4051 non-null   object
#  4   screen_size           4284 non-null   object
#  5   screen_area           4284 non-null   object
#  6   screen_to_body_ratio  4284 non-null   object
#  7   screen_resolution     4284 non-null   object
#  8   rear_camera           4284 non-null   object
#  9   front_camera          4284 non-null   object
#  10  os                    4282 non-null   object
#  11  gpu                   4284 non-null   object
#  12  external_memory       4280 non-null   object
#  13  internal_memory       4208 non-null   object
#  14  cpu                   4172 non-null   object
#  15  dimensions            4284 non-null   object
#  16  weight                4284 non-null   object
#  17  battery               4284 non-null   object
#  18  approximate_price     4284 non-null   object
#  19  sim_card              4284 non-null   object
#  20  net_work              4284 non-null   object
#  21  speed                 4078 non-null   object
#  22  gprs                  4281 non-null   object
#  23  gps                   4281 non-null   object
#  24  wifi                  4283 non-null   object
#  25  nfc                   1265 non-null   object
#  26  usb                   4282 non-null   object
#  27  bluetooth             4282 non-null   object
#  28  radio                 4149 non-null   object
#  29  headphone_jack        4278 non-null   object
# dtypes: object(30)
# memory usage: 1004.2+ KB

# %%
phones_df.dtypes
# Out:
# brand                   object
# technology              object
# touch_screen            object
# display_colors          object
# screen_size             object
# screen_area             object
# screen_to_body_ratio    object
# screen_resolution       object
# rear_camera             object
# front_camera            object
# os                      object
# gpu                     object
# external_memory         object
# internal_memory         object
# cpu                     object
# dimensions              object
# weight                  object
# battery                 object
# approximate_price       object
# sim_card                object
# net_work                object
# speed                   object
# gprs                    object
# gps                     object
# wifi                    object
# nfc                     object
# usb                     object
# bluetooth               object
# radio                   object
# headphone_jack          object
# dtype: object

# %% [markdown]
# ## Tiền xử lý dữ liệu
# - Kiểm tra tập dữ liệu có dữ liệu trùng
# - Thuộc tính `display colors`:
#     - Có các giá trị *Type IPS L, Type OLED ,Type P-OLE,  Type AMOLE, Type Super, Type LTPS* là không đúng với tính chất của thuộc tính
#     - Chuyển giá trị trong cột về cùng một đơn vị, và chuyển về dạng số
# - Thuộc tính `screen size`, `screen area`, `screen to body ratio` chuyển về dạng số
# - thuộc tính `screen resolution` lấy chiều dài nhân chiều rộng để ra số pixel, chuyển `screen resolution` về dạng số
# - Thuộc tính `rear camera`, `front_camera` lấy giá trị là độ phân giải, chuyển thuộc tính về dạng số
# - Thuộc tính `os` lấy tên hệ điều hành và số ghi thế hệ của hệ điều hành
# - Thuộc tính `gpu` xóa khí tự "-"
# - Thuộc tính `external memory`, thay bằng 0 nếu không có external memory, thay bằng 1 nếu điện thoại có external memory
# - Thuộc tình `external memory`chia ra làm hai cột:
#     - Một cột sẽ lưu là 1 nếu điện thoại có external memory, là 0 nếu điện thoại không có external memory
#     - Một cột sẽ lưu là dung lượng của external memory, chuyển cột này về dạng số
# - Thuộc tính `internal_memory` lấy giá trị của dung lượng RAM, chuyển cột về dạng số
# - Thuộc tính `cpu` lấy giá trị xung nhịp, và chuyển các dòng về cùng một đơn vị, chuyển về dạng số
# - Thuộc tính `length`, `width`, `high` về dạng số
# - Thuộc tính `battery` chia ra làm ba cột:
#     - `battery_mah` lưu khả năng trữ điện của pin, đưa về dạng số
#     - `battery_removable` bằng 1 khi có pin rời, bằng 0 khi pin liền
#     - `battery_type1` lưu loại pin
# - Thuộc tính `currency` chuyển cùng về một đơn vị tiền tệ và chuyển về dạng số, thuộc tính `currency` sẽ tách làm 3 lớp {0, 1, 2} tương ứng với mức giá x < 150, 150 <= x <300, x <= 300 (x là giá điện thoại)
# - Thuộc tính `net_work` chia làm 4 cột `_2G`, `_3G`, `_4G`, `_5G`, các cột lưu giá trị {1, 0} thể hiện điện thoại có hổ trợ loại mạng nào
# - Thuộc tính `radio`, `headphone_jack` thay giá trị 1 nếu điện thoại có thuộc tính, bằng 0 nếu điện thoại không có thuộc tính
#
# - **Sau khi tiền xử lý dữ liệu thô xong lưu lại vào file `phones_preprocessed.csv`**

# %%
phones_df = phones_df.drop_duplicates()

# %%
n = phones_df.display_colors.replace(to_replace = ['Type IPS L', 'Type OLED' ,'Type P-OLE',  'Type AMOLE', 'Type Super', 'Type LTPS'], value = 'None')

# %%
phones_df.display_colors = pd.to_numeric(n.replace('256K',  0.256).replace('16M',  16).replace('16M',  16).replace('65K',  0.065)
              .replace('1B',  1000).replace('16М',  16),errors='coerce')
# Out:
# E:\Anaconda\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
phones_df.screen_size = pd.to_numeric(phones_df.screen_size.str.replace('" inc',''), errors='coerce')

# %%
phones_df.screen_area = pd.to_numeric(phones_df.screen_area.str.replace("cm2",'').str.replace(',', '.'), errors='coerce')

# %%
phones_df.screen_to_body_ratio = pd.to_numeric(phones_df.screen_to_body_ratio.str.replace("%",'').str.replace(',', '.'), errors='coerce')

# %%
phones_df.screen_resolution = pd.to_numeric(phones_df.screen_resolution.str.extract(r'( [\d]+)', expand=False), errors='coerce')*pd.to_numeric(phones_df.screen_resolution.str.extract(r'([\d]+)', expand=False), errors='coerce')

# %%
phones_df.rear_camera = pd.to_numeric(phones_df.rear_camera.str.extract(r'([\d.]+)', expand=False), errors='coerce')

# %%
phones_df.front_camera = pd.to_numeric(phones_df.front_camera.str.extract(r'([\d.]+)', expand=False), errors='coerce')

# %%
phones_df.os = phones_df.os.str.extract(r'([a-zA-z ]+ [\d.]+)', expand=False)

# %%
phones_df.gpu = phones_df.gpu.str.replace('-', ' ').str.strip().str.extract(r'([a-zA-z\d]+ [a-zA-z\d]+|[a-zA-z\d]+)', expand=False)

# %%
external_memory = phones_df.external_memory.replace('No', 0)
external_memory.replace(regex = r'([a-zA-Z]+)', value = 1, inplace = True)

# %%
def memory(x):
    if str(x) != 'nan':
        if x.find('GB') != -1:
            return float(re.findall('\d+', x)[0])
        elif x.find('TB') != -1:
            return float(re.findall('\d+', x)[0])*1024
        elif x.find('MB') != -1:
            return float(re.findall('\d+', x)[0])/1024
    else:
        return np.nan

# %%
external_memory_size = phones_df.external_memory.str.extract(r'([\d.]+[a-zA-z ]+)', expand=False).apply(lambda x: memory(x))

# %%
phones_df.external_memory = external_memory
phones_df['external_memory_size'] = external_memory_size
# Out:
# <ipython-input-25-453564e2b126>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phones_df['external_memory_size'] = external_memory_size

# %%
phones_df.internal_memory = phones_df.internal_memory.str.extract(r'([\d ]+[a-zA-Z ]+RAM)', expand = False).str.extract(r'([\d ]+[a-zA-Z]+)',expand = False).apply(lambda x: memory(x))

# %%
def cpu(x):
    if str(x) != 'nan':
        if x.find('GHz') != -1:
            return float(re.findall('[\d.]+', x)[0])
        elif x.find('MHz') != -1:
            return float(re.findall('[\d.]+', x)[0])*0.001
    else:
        return np.nan

# %%
phones_df.cpu = phones_df.cpu.str.extract(r'([\d.]+ GHz|[\d.]+ MHz|[\d.]+MHz|[\d.]+GHz)', expand=False).apply(lambda x: cpu(x))

# %%
phones_df['length'] = pd.to_numeric(phones_df.dimensions.str.extract(r'([\d.]+)', expand=False), errors='coerce')
# Out:
# <ipython-input-29-47f2ca6061f8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phones_df['length'] = pd.to_numeric(phones_df.dimensions.str.extract(r'([\d.]+)', expand=False), errors='coerce')

# %%
phones_df['width'] = pd.to_numeric(phones_df.dimensions.str.extract(r'( [\d.]+)', expand=False), errors='coerce')
# Out:
# <ipython-input-30-8b2e3e14b0e3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phones_df['width'] = pd.to_numeric(phones_df.dimensions.str.extract(r'( [\d.]+)', expand=False), errors='coerce')

# %%
phones_df['high'] = pd.to_numeric(phones_df.dimensions.str.extract(r'( [\d.]+ [a-zA-z])', expand=False).str.replace(' m',''), errors='coerce')
# Out:
# <ipython-input-31-43422f373bf3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phones_df['high'] = pd.to_numeric(phones_df.dimensions.str.extract(r'( [\d.]+ [a-zA-z])', expand=False).str.replace(' m',''), errors='coerce')

# %%
phones_df.weight = pd.to_numeric(phones_df.weight.str.extract(r'([\d.]+)', expand=False).replace('0', np.nan), errors='coerce')

# %%
def type(battery):
    if battery.find('Li-Ion') != -1:
        return 'Li-Ion'
    elif battery.find('Li-Po') != -1:
        return 'Li-Po'
    else:
        return np.nan

# %%
phones_df['battery_mah'] = pd.to_numeric(phones_df.battery.str.extract(r'([\d.]+)', expand=False), errors='coerce')
phones_df['battery_removable'] = phones_df.battery.str.replace('\xa0', '').str.contains('Removable')
phones_df['battery_removable'].replace(True, 1, inplace=True)
phones_df['battery_removable'].replace(False, 0, inplace=True)
phones_df['battery_type'] = phones_df.battery.apply(lambda x: type(x))
# Out:
# <ipython-input-34-f1b2450b13c6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phones_df['battery_mah'] = pd.to_numeric(phones_df.battery.str.extract(r'([\d.]+)', expand=False), errors='coerce')
# <ipython-input-34-f1b2450b13c6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phones_df['battery_removable'] = phones_df.battery.str.replace('\xa0', '').str.contains('Removable')
# E:\Anaconda\lib\site-packages\pandas\core\generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# <ipython-input-34-f1b2450b13c6>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phones_df['battery_type'] = phones_df.battery.apply(lambda x: type(x))

# %%
currency = ['EU', 'USD', 'INR', 'BTC', '€', '₹']

# %%
phones_df['price'] = pd.to_numeric(phones_df.approximate_price.str.extract(r'([\d.]+)',expand=False), errors='coerce').copy()
# Out:
# <ipython-input-36-92d7fc9ad84c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phones_df['price'] = pd.to_numeric(phones_df.approximate_price.str.extract(r'([\d.]+)',expand=False), errors='coerce').copy()

# %%
for i in  currency:
    phones_df[i] = phones_df.approximate_price.str.contains(i).copy().replace(True, 1).replace(False, 0) 
a = []
for i in  phones_df.index:
        j = '$'
        if j  in phones_df.approximate_price[i]:
            a.append(1)
        else:
            a.append(0)
# Out:
# <ipython-input-37-fba4d549eeea>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phones_df[i] = phones_df.approximate_price.str.contains(i).copy().replace(True, 1).replace(False, 0)

# %%
phones_df['real_price'] = phones_df.price * (phones_df.EU* 1 + phones_df.USD*0.82 + phones_df.INR* 0.011 + phones_df[currency[4]] * 1 + phones_df[currency[5]]*0.011)
# Out:
# <ipython-input-38-de125d261f90>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phones_df['real_price'] = phones_df.price * (phones_df.EU* 1 + phones_df.USD*0.82 + phones_df.INR* 0.011 + phones_df[currency[4]] * 1 + phones_df[currency[5]]*0.011)

# %%
phones_df['_2G'] = phones_df.net_work.str.contains('GSM').copy().replace(True, 1).replace(False, 0)
phones_df['_3G'] = phones_df.net_work.str.contains('CDMA2000| EVDO|UMTS|HSPA').copy().replace(True, 1).replace(False, 0)
phones_df['_4G'] = phones_df.net_work.str.contains('LTE').copy().replace(True, 1).replace(False, 0)
phones_df['_5G'] =  phones_df.net_work.str.contains('5G').copy().replace(True, 1).replace(False, 0)
# Out:
# <ipython-input-39-7e69e2ba3337>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phones_df['_2G'] = phones_df.net_work.str.contains('GSM').copy().replace(True, 1).replace(False, 0)
# <ipython-input-39-7e69e2ba3337>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phones_df['_3G'] = phones_df.net_work.str.contains('CDMA2000| EVDO|UMTS|HSPA').copy().replace(True, 1).replace(False, 0)
# <ipython-input-39-7e69e2ba3337>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phones_df['_4G'] = phones_df.net_work.str.contains('LTE').copy().replace(True, 1).replace(False, 0)
# <ipython-input-39-7e69e2ba3337>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phones_df['_5G'] =  phones_df.net_work.str.contains('5G').copy().replace(True, 1).replace(False, 0)

# %%
phones_df._2G.value_counts()
# Out:
# 1.0    4196
# 0.0      46
# Name: _2G, dtype: int64

# %%
phones_df._3G.value_counts()
# Out:
# 1.0    4003
# 0.0     239
# Name: _3G, dtype: int64

# %%
phones_df._4G.value_counts()
# Out:
# 1.0    2376
# 0.0    1866
# Name: _4G, dtype: int64

# %%
phones_df._5G.value_counts()
# Out:
# 0.0    4054
# 1.0     188
# Name: _5G, dtype: int64

# %%
phones_df.radio.replace('No',  0, inplace = True)
phones_df.radio.replace(regex = r'([a-zA-Z]+)', value = 1, inplace = True)

# %%
phones_df.headphone_jack.replace(['No, included adaptor for 3.5mm', 'No'],value = 0, inplace = True)
phones_df.headphone_jack.replace(['Yes', 'TBD', '1'],value = 1, inplace = True)

# %%
columns_drop = ['dimensions', 'battery', 'approximate_price', 'sim_card', 'net_work', 'gpu',
                'speed', 'gprs', 'gps', 'wifi', 'nfc', 'usb', 'bluetooth', 'price', 'EU',
                'USD', 'INR', 'BTC', currency[4], currency[5], '_2G', '_3G', '_5G', 'external_memory_size', 'touch_screen']

# %%
phones_df.drop(columns = columns_drop, inplace = True)
phones_df
# Out:
# E:\Anaconda\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#      brand     technology  display_colors  screen_size  screen_area  \
# 0       A1        IPS LCD          16.000         6.26         97.8
# 1       A1        IPS LCD          16.000         5.50         78.1
# 2     Acer        IPS LCD          16.000         5.00         68.9
# 3     Acer        IPS LCD          16.000         5.50         83.4
# 4     Acer        IPS LCD          16.000         5.00         68.9
# ...    ...            ...             ...          ...          ...
# 4279   Zte            TFT          16.000         4.30         52.6
# 4280   Zte            TFT          16.000         4.30         52.6
# 4281   Zte            TFT           0.065         0.00          NaN
# 4282   Zte  AMOLED or LCD           0.256         3.50         34.9
# 4283   Zte            TFT           0.256         2.80         24.3
#
#       screen_to_body_ratio  screen_resolution  rear_camera  front_camera  \
# 0                     82.1          1094400.0        13.00           8.0
# 1                     77.1          1036800.0        13.00           8.0
# 2                     65.3           921600.0         8.00           2.0
# 3                     71.7          2073600.0        13.00           5.0
# 4                     66.4           921600.0         8.00           5.0
# ...                    ...                ...          ...           ...
# 4279                  61.7           384000.0         5.00           0.0
# 4280                  60.4           384000.0         5.00           0.0
# 4281                   NaN            76800.0         2.00           0.0
# 4282                  53.2           384000.0         3.15           0.0
# 4283                  43.3            76800.0         3.15           0.0
#
#                                os  ...  radio  headphone_jack  length  width  \
# 0                     Android 9.0  ...    1.0             1.0   151.7   75.8
# 1                     Android 8.1  ...    1.0             1.0   147.1   68.8
# 2                     Android 6.0  ...    1.0             1.0   145.5   72.5
# 3                     Android 6.0  ...    1.0             1.0   153.8   75.6
# 4                     Android 6.0  ...    1.0             1.0   145.7   71.2
# ...                           ...  ...    ...             ...     ...    ...
# 4279                  Android 2.3  ...    NaN             1.0   125.9   67.8
# 4280  Microsoft Windows Phone 7.5  ...    1.0             1.0   128.6   67.8
# 4281                  Android 2.2  ...    1.0             1.0   116.0   56.5
# 4282                  Android 2.1  ...    1.0             1.0   116.0   56.5
# 4283                  Android 2.1  ...    1.0             1.0   102.0   55.0
#
#       high  battery_mah  battery_removable  battery_type  real_price  _4G
# 0      8.1         3200                0.0        Li-Ion       150.0  1.0
# 1      8.7         2900                0.0        Li-Ion       120.0  1.0
# 2      8.5         2000                1.0        Li-Ion       120.0  1.0
# 3      8.5         4080                0.0         Li-Po       250.0  1.0
# 4      8.4         2000                1.0        Li-Ion       110.0  1.0
# ...    ...          ...                ...           ...         ...  ...
# 4279  10.4         1400                1.0        Li-Ion       250.0  0.0
# 4280  10.5         1400                1.0        Li-Ion       210.0  0.0
# 4281  11.8            0                0.0           NaN       220.0  0.0
# 4282  11.8         1250                1.0        Li-Ion       170.0  0.0
# 4283  14.5         1100                1.0        Li-Ion       180.0  0.0
#
# [4242 rows x 24 columns]

# %%
phones_df  = phones_df[phones_df['real_price'] != 0].copy()

# %%
for i in phones_df.real_price:
    if i < 150:
        phones_df.real_price.replace(i, 0, inplace = True)
for i in phones_df.real_price:
    if (i >= 150 and i < 300):
        phones_df.real_price.replace(i, 1, inplace = True)
    elif (i >= 300):
        phones_df.real_price.replace(i, 2, inplace = True)

# %%
phones_df.to_csv('phones_preprocessed.csv', index = False)

# %%
phones_df
# Out:
#      brand     technology  display_colors  screen_size  screen_area  \
# 0       A1        IPS LCD          16.000         6.26         97.8
# 1       A1        IPS LCD          16.000         5.50         78.1
# 2     Acer        IPS LCD          16.000         5.00         68.9
# 3     Acer        IPS LCD          16.000         5.50         83.4
# 4     Acer        IPS LCD          16.000         5.00         68.9
# ...    ...            ...             ...          ...          ...
# 4279   Zte            TFT          16.000         4.30         52.6
# 4280   Zte            TFT          16.000         4.30         52.6
# 4281   Zte            TFT           0.065         0.00          NaN
# 4282   Zte  AMOLED or LCD           0.256         3.50         34.9
# 4283   Zte            TFT           0.256         2.80         24.3
#
#       screen_to_body_ratio  screen_resolution  rear_camera  front_camera  \
# 0                     82.1          1094400.0        13.00           8.0
# 1                     77.1          1036800.0        13.00           8.0
# 2                     65.3           921600.0         8.00           2.0
# 3                     71.7          2073600.0        13.00           5.0
# 4                     66.4           921600.0         8.00           5.0
# ...                    ...                ...          ...           ...
# 4279                  61.7           384000.0         5.00           0.0
# 4280                  60.4           384000.0         5.00           0.0
# 4281                   NaN            76800.0         2.00           0.0
# 4282                  53.2           384000.0         3.15           0.0
# 4283                  43.3            76800.0         3.15           0.0
#
#                                os  ...  radio  headphone_jack  length  width  \
# 0                     Android 9.0  ...    1.0             1.0   151.7   75.8
# 1                     Android 8.1  ...    1.0             1.0   147.1   68.8
# 2                     Android 6.0  ...    1.0             1.0   145.5   72.5
# 3                     Android 6.0  ...    1.0             1.0   153.8   75.6
# 4                     Android 6.0  ...    1.0             1.0   145.7   71.2
# ...                           ...  ...    ...             ...     ...    ...
# 4279                  Android 2.3  ...    NaN             1.0   125.9   67.8
# 4280  Microsoft Windows Phone 7.5  ...    1.0             1.0   128.6   67.8
# 4281                  Android 2.2  ...    1.0             1.0   116.0   56.5
# 4282                  Android 2.1  ...    1.0             1.0   116.0   56.5
# 4283                  Android 2.1  ...    1.0             1.0   102.0   55.0
#
#       high  battery_mah  battery_removable  battery_type  real_price  _4G
# 0      8.1         3200                0.0        Li-Ion         1.0  1.0
# 1      8.7         2900                0.0        Li-Ion         0.0  1.0
# 2      8.5         2000                1.0        Li-Ion         0.0  1.0
# 3      8.5         4080                0.0         Li-Po         1.0  1.0
# 4      8.4         2000                1.0        Li-Ion         0.0  1.0
# ...    ...          ...                ...           ...         ...  ...
# 4279  10.4         1400                1.0        Li-Ion         1.0  0.0
# 4280  10.5         1400                1.0        Li-Ion         1.0  0.0
# 4281  11.8            0                0.0           NaN         1.0  0.0
# 4282  11.8         1250                1.0        Li-Ion         1.0  0.0
# 4283  14.5         1100                1.0        Li-Ion         1.0  0.0
#
# [4198 rows x 24 columns]

# %%
phones_df.dtypes
# Out:
# brand                    object
# technology               object
# display_colors          float64
# screen_size             float64
# screen_area             float64
# screen_to_body_ratio    float64
# screen_resolution       float64
# rear_camera             float64
# front_camera            float64
# os                       object
# external_memory         float64
# internal_memory         float64
# cpu                     float64
# weight                  float64
# radio                   float64
# headphone_jack          float64
# length                  float64
# width                   float64
# high                    float64
# battery_mah               int64
# battery_removable       float64
# battery_type             object
# real_price              float64
# _4G                     float64
# dtype: object
